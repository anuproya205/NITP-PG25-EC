# %% [markdown]
# <a href="https://colab.research.google.com/github/anuproya205/NITP-PG25-EC/blob/main/Python_Sets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sets in Python
#
# ####unorders collection of unique element we can add remove element

# %%
## Creating a set without values/ empty set
set_var=set()
print(set_var)
print(type(set_var))
# Out:
# set()
# <class 'set'>

# %%
## Creating a set with values
fruits= {"","apple","mango","banana"}
print(fruits)
print(type(fruits))
# Out:
# {'', 'mango', 'apple', 'banana'}
# <class 'set'>

# %%
#adding an element
fruits.add("Orange")
print(fruits)

# %%
# Difference
set1={1, 2, 3}
set2={2, 3, 4}
print(set1.difference(set2))## remove anything from set1 that is also in set2
print(set2.difference(set1))# remove anything from set2 that is also in set1
# Out:
# {1}
# {4}

# %%
#1) No Duplicate Values
a={1,2,3,4,4,5,5,6}
print(a)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
#2) Unordered
a={"A","B ", "C"}
print(a)
# Out:
# {'B ', 'A', 'C'}

# %%
#3 Mutable ---we can add and remove element
