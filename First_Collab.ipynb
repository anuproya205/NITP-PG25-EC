# %% [markdown]
# <a href="https://colab.research.google.com/github/anuproya205/NITP-PG25-EC/blob/main/First_Collab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("colab started")
1+1
# Out:
# colab started
# 2

# %% [markdown]
# #Various Data Types in Python

# %%
1+1
# Out:
# 2

# %%
4*5
# Out:
# 20

# %%
10/2
# Out:
# 5.0

# %% [markdown]
# ###Datatype

# %%
2*5
# Out:
# 10

# %%
10%2
# Out:
# 0

# %%
10**2
# Out:
# 100

# %%
10*"str"
# Out:
# 'strstrstrstrstrstrstrstrstrstr'

# %% [markdown]
# ### Check the data type

# %%
type(1)
# Out:
# int

# %%
type("hello")
# Out:
# str

# %%
type(True)
# Out:
# bool

# %% [markdown]
# ###Strings

# %%
"hello"
# Out:
# 'hello'

# %%
'Anupriya'
# Out:
# 'Anupriya'

# %%
type("Anupriya")
# Out:
# str

# %% [markdown]
# ###Variable Assignment

# %%
# Syntax
#var_name=values

a=10

# %%
type(a)
# Out:
# int

# %%
a="anu"
type(a)
# Out:
# str

# %%
## Mathematical operation with variable Assignment
a=10
b=20

# %%
print(a*b)
print(a/b)
print(a%b)
print((a*b)+(a/b))
# Out:
# 200
# 0.5
# 10
# 200.5
