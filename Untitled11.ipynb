# %% [markdown]
# <a href="https://colab.research.google.com/github/anuproya205/NITP-PG25-EC/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout

print("TensorFlow version:", tf.__version__)
#Generate BPSK
# Out:
# TensorFlow version: 2.20.0

# %%
#Generate BPSK

#Create a new cell
def generate_bpsk(num_symbols=1000):

    bits = np.random.randint(0, 2, num_symbols)

    symbols = 2 * bits - 1

    return symbols.astype(complex)

# %%
bpsk = generate_bpsk(20)

print(bpsk)
# Out:
# [-1.+0.j  1.+0.j -1.+0.j  1.+0.j  1.+0.j -1.+0.j -1.+0.j -1.+0.j -1.+0.j
#   1.+0.j -1.+0.j  1.+0.j  1.+0.j  1.+0.j -1.+0.j  1.+0.j  1.+0.j -1.+0.j
#   1.+0.j -1.+0.j]

# %%
bpsk = generate_bpsk(1000)

plt.figure(figsize=(5, 5))
plt.scatter(bpsk.real, bpsk.imag, alpha=0.5)

plt.xlabel("In-phase (I)")
plt.ylabel("Quadrature (Q)")
plt.title("BPSK Constellation")
plt.grid()
plt.show()

# %%
def generate_qpsk(num_symbols=1000):

    bits = np.random.randint(0, 2, num_symbols * 2)

    bits = bits.reshape(-1, 2)

    symbol_map = {
        (0, 0): 1 + 1j,
        (0, 1): -1 + 1j,
        (1, 1): -1 - 1j,
        (1, 0): 1 - 1j
    }

    symbols = np.array([
        symbol_map[tuple(b)] for b in bits
    ])

    symbols = symbols / np.sqrt(2)

    return symbols
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_871/3784384089.py in <cell line: 0>()
#      22
#      23 plt.figure(figsize=(5, 5))
# ---> 24 plt.scatter(qpsk.real, qpsk.imag, alpha=0.5)
#      25
#      26 plt.xlabel("In-phase (I)")
#
# NameError: name 'qpsk' is not defined

# %%
qpsk = generate_qpsk(1000)

plt.figure(figsize=(5, 5))
plt.scatter(qpsk.real, qpsk.imag, alpha=0.5)

plt.xlabel("In-phase (I)")
plt.ylabel("Quadrature (Q)")
plt.title("QPSK Constellation")
plt.grid()
plt.show()
