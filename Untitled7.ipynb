# %% [markdown]
# <a href="https://colab.research.google.com/github/anuproya205/NITP-PG25-EC/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Seaborn

# %% [markdown]
# ##Distributio plots
#
#
#
#
# *   Displot
# *   Joinplot
# *   Pairplot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
