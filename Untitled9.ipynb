# %% [markdown]
# <a href="https://colab.research.google.com/github/anuproya205/NITP-PG25-EC/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #OOPs tutorial in python
# #### (class, inheritance , instace creation , data abstraction , encapsulation )

# %% [markdown]
# OOPs: Object oriented programming (instead of keeping data and functions separately , we can put relsted data and functions together inside an object)

# %%
# 1) class- class is a blueprint(here student is class)
class Student:
  pass


# Object-an actual things created from that bueprint
Student1= Student()   #Student is class and Student1,2 is object
Student2= Student()

# %%
#creating an object soil moisture dataset
class SoilMoistureData:
  pass
#now create an object
data = SoilMoistureData()
