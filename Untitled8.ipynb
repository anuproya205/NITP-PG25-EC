# %% [markdown]
# <a href="https://colab.research.google.com/github/anuproya205/NITP-PG25-EC/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Functions in Python
#
#
# *   Why Functions
# *   Function Definition
# *   Positonal and Keyword Arguements in Functon

# %%
num=24
print(num)
# Out:
# 24

# %%
#examples ---with helps of function we dont need to write same code again and again

def add(a,b): # def ---define a function , add---function name , (a,b)--paramters(i/p to the funtion)
  return a+b #  return --send the result back

  print(add(10, 20))
 # print(add(2,4))

# %%
# Baisc Syntax

def function_name(parameters):
  # code
   return result

def add(c, d):
  return c+d

# %%
#Return ----send the result back
def square(x):
  return x*x
print(square(4))
# Out:
# 16

# %%
# Calling a function
def greet(name):
   print("Hello", name)
greet("Anu")

# Without parameter calling
def greet():
  print("Hello")
  print("good mprning")
  print("Namste landon")
greet()


# parameter calling
def greet(name):
   print("Hello", name)
greet("Anu")

#  parameter calling with Return key

def add(a,b):
  return a+b
print(add(10, 20))
# Out:
# Hello Anu
# Hello
# good mprning
# Namste landon
# Hello Anu

# %%
#Difference between print and return
#Function returning multiple values
def calculate(a,b):
   return a+b, a-b
sum1, diff= calculate(10,5)
print(sum1)
print(diff)
# Out:
# 15
# 5

# %%
#Default Parameters
def greet(name="Student"):
    print("Hello",name)
greet()
greet("Mohan")
# Out:
# Hello Student
# Hello Mohan

# %%
#keyword agrument
def student(name, age):
  print(name)
  print(age)
student(name="Anu",age=25)
# Out:
# Anu
# 25

# %%
#Positional agrument
student("priya", 25)
# Out:
# priya
# 25

# %% [markdown]
# ###Variable length argument(when we dont know how man number user will pass)

# %%
"""def add(*numbers):
  print(numbers)
add(2,4,6)"""

def add(*numbers):
    result= sum(numbers)
    print(result)
add(2,3)
# Out:
# 5

# %%
#Keyword Variable Arguments
def student(**details):
   print(details)

student(Name="priya",age =25,city="patna")
# Out:
# {'Name': 'priya', 'age': 25, 'city': 'patna'}

# %%
#Local variable
def test():
    x=10
    print(x)
test()


#Global variable

x=50
def test():
  print(x)
test()
# Out:
# 10
# 50

# %% [markdown]
# # Built in function
# print()
# len(), sum(), max(), min(), type(), input(), range()
