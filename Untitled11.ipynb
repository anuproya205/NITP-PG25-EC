# %% [markdown]
# <a href="https://colab.research.google.com/github/anuproya205/NITP-PG25-EC/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# 1. OBSERVED SENTINEL-1 VV

sigma_vv_obs = 0.0287

print("Observed VV =", sigma_vv_obs)

# 2. RADAR / SOIL PARAMETERS


theta_deg = 40
lambda_cm = 5.6
s_cm = 1.0

theta = np.deg2rad(theta_deg)

cos_theta = np.cos(theta)
sin_theta = np.sin(theta)

sec_theta = 1 / cos_theta
cot_theta = 1 / np.tan(theta)

# Radar wavenumber
k = 2 * np.pi / lambda_cm

print("Incidence angle =", theta_deg, "degree")
print("Wavelength      =", lambda_cm, "cm")
print("RMS roughness   =", s_cm, "cm")
print("Wavenumber k    =", k)

# 3. FDP LOOK-UP TABLE

lut = pd.DataFrame({

    "LAI": [
        7.49,
        7.57,
        7.78,
        7.12,
        7.22,
        6.15,
        7.07,
        4.58,
        6.11,
        8.77,
        8.93,
        8.67,
        8.80,
        8.26,
        8.33,
        6.34,
        7.14,
        7.47,
        5.66,
        5.16,
        6.22
    ],

    "SM": [
        0.4694,
        0.4694,
        0.4694,
        0.2219,
        0.2219,
        0.2219,
        0.4417,
        0.4417,
        0.4417,
        0.3413,
        0.3413,
        0.3413,
        0.4375,
        0.4375,
        0.4375,
        0.4184,
        0.4184,
        0.4184,
        0.436666667,
        0.441666667,
        0.435333333
    ],


    "VV_FDP": [
        0.03859,
        0.04903,
        0.03493,
        0.02832,
        0.02317,
        0.03057,
        0.04429,
        0.02798,
        0.03680,
        0.05130,
        0.04578,
        0.04100,
        0.04121,
        0.04840,
        0.04711,
        0.05173,
        0.03546,
        0.04658,
        0.05107,
        0.05242,
        0.04297
    ]
})


# 4. DUBOIS MODEL
# sigma_VV_soil =
# 10^(-1.138)
# * cos(theta)^1.528
# * 10^(0.008*cot(theta)*SM)
# * (k*s)^(0.71*sin(theta))
# ============================================================

def dubois_model_vv(SM):

    sigma_soil_vv = (
        10**(-1.138)
        * cos_theta**1.528
        * 10**(
            0.008
            * cot_theta
            * SM
        )
        * (k * s_cm)**(
            0.71 * sin_theta
        )
    )

    return sigma_soil_vv


# Calculate soil VV for every LUT row
lut["sigma_soil_VV"] = lut["SM"].apply(
    dubois_model_vv
)



# 5. WCM A AND B SEARCH RANGE

A_min = 0.01
A_max = 0.03
A_step = 0.001

B_min = 0.10
B_max = 0.20
B_step = 0.01


A_values = np.arange(
    A_min,
    A_max + A_step,
    A_step
)

B_values = np.arange(
    B_min,
    B_max + B_step,
    B_step
)

# 6. WCM CALCULATION

results = []

for row_number, row in lut.iterrows():

    # Take LAI and SM from SAME LUT row
    LAI = row["LAI"]
    SM = row["SM"]

    # Soil backscatter calculated from this row's SM
    sigma_soil_vv = row["sigma_soil_VV"]

    #taking v1 and v2 equal
    # V1 = V2 = LAI


    V1 = LAI
    V2 = LAI
    # Search A

    for A in A_values:

        # Search B

        for B in B_values:

            # WCM EQUATION 1

            # tau^2 = exp(-2 B V2 sec(theta))
            tau_squared = np.exp(
                -2
                * B
                * V2
                * sec_theta
            )

            # WCM VEGETATION BACKSCATTER

            # sigma_veg = A V1 cos(theta)(1 - tau^2)

            sigma_veg = (
                A
                * V1
                * cos_theta
                * (1 - tau_squared)
            )
            # TOTAL WCM BACKSCATTER
            # sigma_total = sigma_veg + tau^2 * sigma_soil
            # =================================================

            sigma_vv_total = (
                sigma_veg
                + tau_squared * sigma_soil_vv
            )

            # ERROR
            difference = (
                sigma_vv_obs
                - sigma_vv_total
            )
            # For one observed VV value:
            # RMSE = absolute error

            cost = np.sqrt(
                difference**2
            )


            # Store result
            results.append([
                row_number + 1,
                LAI,
                SM,
                sigma_soil_vv,
                A,
                B,
                tau_squared,
                sigma_veg,
                sigma_vv_total,
                difference,
                cost
            ])

# 7. CREATE FINAL WCM LUT

columns = [
    "LUT_Row",
    "LAI",
    "SM",
    "sigma_soil_VV",
    "A",
    "B",
    "tau_squared",
    "sigma_veg",
    "sigma_vv_total",
    "difference",
    "cost"
]

wcm_lut = pd.DataFrame(
    results,
    columns=columns
)

# 8. FIND MINIMUM COST
best_index = wcm_lut["cost"].idxmin()

best_result = wcm_lut.loc[
    best_index
]
# 9. PRINT BEST RESULT
print("\n")
print("=" * 70)
print("      BEST WCM RESULT")
print("=" * 70)

print(
    f"Observed VV             = "
    f"{sigma_vv_obs:.15f}"
)

print(
    f"LUT Row                 = "
    f"{int(best_result['LUT_Row'])}"
)

print(
    f"Best LAI                = "
    f"{best_result['LAI']:.6f}"
)

print(
    f"Best SM                 = "
    f"{best_result['SM']:.9f}"
)

print(
    f"Soil VV from Dubois     = "
    f"{best_result['sigma_soil_VV']:.15f}"
)

print(
    f"Best A                  = "
    f"{best_result['A']:.8f}"
)

print(
    f"Best B                  = "
    f"{best_result['B']:.8f}"
)

print(
    f"Tau squared             = "
    f"{best_result['tau_squared']:.15f}"
)

print(
    f"Vegetation VV           = "
    f"{best_result['sigma_veg']:.15f}"
)

print(
    f"Calculated Total VV     = "
    f"{best_result['sigma_vv_total']:.15f}"
)

print(
    f"Difference              = "
    f"{best_result['difference']:.15f}"
)

print(
    f"Minimum Cost            = "
    f"{best_result['cost']:.15f}"
)


# ============================================================
# 10. DISPLAY COMPLETE 21-ROW LUT
# ============================================================

print("\n")
print("=" * 70)
print("          21 FDP LUT ROWS WITH DUBOIS SOIL VV")
print("=" * 70)

print(
    lut[
        [
            "LAI",
            "SM",
            "sigma_soil_VV",
            "VV_FDP"
        ]
    ].to_string(
        index=True,
        float_format=lambda x: f"{x:.9f}"
    )
)

# 11. DISPLAY 20 LOWEST-COST WCM COMBINATIONS


best_20 = (
    wcm_lut
    .sort_values(
        by="cost",
        ascending=True
    )
    .head(20)
)


print("\n")
print("=" * 70)
print("          20 LOWEST-COST WCM COMBINATIONS")
print("=" * 70)

print(
    best_20[
        [
            "LUT_Row",
            "LAI",
            "SM",
            "A",
            "B",
            "tau_squared",
            "sigma_soil_VV",
            "sigma_veg",
            "sigma_vv_total",
            "difference",
            "cost"
        ]
    ].to_string(
        index=False,
        float_format=lambda x: f"{x:.12f}"
    )
)
# Out:
# Observed VV = 0.0287
# Incidence angle = 40 degree
# Wavelength      = 5.6 cm
# RMS roughness   = 1.0 cm
# Wavenumber k    = 1.121997376282069
#
#
# ======================================================================
#       BEST WCM RESULT
# ======================================================================
# Observed VV             = 0.028700000000000
# LUT Row                 = 8
# Best LAI                = 4.580000
# Best SM                 = 0.441700000
# Soil VV from Dubois     = 0.051542618502703
# Best A                  = 0.01000000
# Best B                  = 0.21000000
# Tau squared             = 0.081180398254780
# Vegetation VV           = 0.032236634576674
# Calculated Total VV     = 0.036420884873818
# Difference              = -0.007720884873818
# Minimum Cost            = 0.007720884873818
#
#
# ======================================================================
#           21 FDP LUT ROWS WITH DUBOIS SOIL VV
# ======================================================================
#            LAI          SM  sigma_soil_VV      VV_FDP
# 0  7.490000000 0.469400000    0.051573971 0.038590000
# 1  7.570000000 0.469400000    0.051573971 0.049030000
# 2  7.780000000 0.469400000    0.051573971 0.034930000
# 3  7.120000000 0.221900000    0.051294512 0.028320000
# 4  7.220000000 0.221900000    0.051294512 0.023170000
# 5  6.150000000 0.221900000    0.051294512 0.030570000
# 6  7.070000000 0.441700000    0.051542619 0.044290000
# 7  4.580000000 0.441700000    0.051542619 0.027980000
# 8  6.110000000 0.441700000    0.051542619 0.036800000
# 9  8.770000000 0.341300000    0.051429140 0.051300000
# 10 8.930000000 0.341300000    0.051429140 0.045780000
# 11 8.670000000 0.341300000    0.051429140 0.041000000
# 12 8.800000000 0.437500000    0.051537866 0.041210000
# 13 8.260000000 0.437500000    0.051537866 0.048400000
# 14 8.330000000 0.437500000    0.051537866 0.047110000
# 15 6.340000000 0.418400000    0.051516261 0.051730000
# 16 7.140000000 0.418400000    0.051516261 0.035460000
# 17 7.470000000 0.418400000    0.051516261 0.046580000
# 18 5.660000000 0.436666667    0.051536924 0.051070000
# 19 5.160000000 0.441666667    0.051542581 0.052420000
# 20 6.220000000 0.435333333    0.051535415 0.042970000
#
#
# ======================================================================
#           20 LOWEST-COST WCM COMBINATIONS
# ======================================================================
#  LUT_Row            LAI             SM              A              B    tau_squared  sigma_soil_VV      sigma_veg  sigma_vv_total      difference           cost
#        8 4.580000000000 0.441700000000 0.010000000000 0.210000000000 0.081180398255 0.051542618503 0.032236634577  0.036420884874 -0.007720884874 0.007720884874
#        8 4.580000000000 0.441700000000 0.010000000000 0.200000000000 0.091491779336 0.051542618503 0.031874861468  0.036590587346 -0.007890587346 0.007890587346
#        8 4.580000000000 0.441700000000 0.010000000000 0.190000000000 0.103112892596 0.051542618503 0.031467136621  0.036781845106 -0.008081845106 0.008081845106
#        8 4.580000000000 0.441700000000 0.010000000000 0.180000000000 0.116210097744 0.051542618503 0.031007623333  0.036997396067 -0.008297396067 0.008297396067
#        8 4.580000000000 0.441700000000 0.010000000000 0.170000000000 0.130970885189 0.051542618503 0.030489743533  0.037240325904 -0.008540325904 0.008540325904
#        8 4.580000000000 0.441700000000 0.010000000000 0.160000000000 0.147606560017 0.051542618503 0.029906083619  0.037514112230 -0.008814112230 0.008814112230
#        8 4.580000000000 0.441700000000 0.010000000000 0.150000000000 0.166355266887 0.051542618503 0.029248288322  0.037822674379 -0.009122674379 0.009122674379
#        8 4.580000000000 0.441700000000 0.010000000000 0.140000000000 0.187485399143 0.051542618503 0.028506941108  0.038170429511 -0.009470429511 0.009470429511
#        8 4.580000000000 0.441700000000 0.010000000000 0.130000000000 0.211299440948 0.051542618503 0.027671429369  0.038562355844 -0.009862355844 0.009862355844
#        8 4.580000000000 0.441700000000 0.010000000000 0.120000000000 0.238138297430 0.051542618503 0.026729792504  0.039004063920 -0.010304063920 0.010304063920
#        8 4.580000000000 0.441700000000 0.010000000000 0.110000000000 0.268386174845 0.051542618503 0.025668550701  0.039501876923 -0.010801876923 0.010801876923
#        8 4.580000000000 0.441700000000 0.011000000000 0.210000000000 0.081180398255 0.051542618503 0.035460298034  0.039644548331 -0.010944548331 0.010944548331
#        8 4.580000000000 0.441700000000 0.011000000000 0.200000000000 0.091491779336 0.051542618503 0.035062347614  0.039778073493 -0.011078073493 0.011078073493
#        8 4.580000000000 0.441700000000 0.011000000000 0.190000000000 0.103112892596 0.051542618503 0.034613850283  0.039928558769 -0.011228558769 0.011228558769
#        8 4.580000000000 0.441700000000 0.010000000000 0.100000000000 0.302476080602 0.051542618503 0.024472511966  0.040062921194 -0.011362921194 0.011362921194
#        8 4.580000000000 0.441700000000 0.011000000000 0.180000000000 0.116210097744 0.051542618503 0.034108385666  0.040098158400 -0.011398158400 0.011398158400
#       20 5.160000000000 0.441666667000 0.010000000000 0.210000000000 0.059067248597 0.051542580786 0.037193089367  0.040237567800 -0.011537567800 0.011537567800
#        8 4.580000000000 0.441700000000 0.011000000000 0.170000000000 0.130970885189 0.051542618503 0.033538717887  0.040289300257 -0.011589300257 0.011589300257
#       20 5.160000000000 0.441666667000 0.010000000000 0.200000000000 0.067585579129 0.051542580786 0.036856377707  0.040339912879 -0.011639912879 0.011639912879
#       20 5.160000000000 0.441666667000 0.010000000000 0.190000000000 0.077332373096 0.051542580786 0.036471107475  0.040457017563 -0.011757017563 0.011757017563
