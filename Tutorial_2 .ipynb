# %% [markdown]
# <a href="https://colab.research.google.com/github/anuproya205/NITP-PG25-EC/blob/main/Tutorial_2%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Python Data Structure and Boolean
# 1. Boolean
# 1. Boolean and Logical Operator
# 2. Lists
# 3. Comparision Operator
# 4. Dictionaries
# 5. Tuples
# 6. sets

# %% [markdown]
# Boolean variable

# %%
False
# Out:
# False

# %%
print(True, False)
# Out:
# True False

# %%
type(True)
# Out:
# bool

# %%
my_str="Anupriya"

# %%
my_str.isalnum()
# Out:
# True

# %%
my_str.istitle()
# Out:
# True

# %% [markdown]
# ##Boolean and Logical Operators

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
True or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or False
# Out:
# False

# %% [markdown]
# ##Lists

# %%
type([])
# Out:
# list

# %%
lst_example=[]
type(lst_example)
# Out:
# list

# %%
lst=list()
type(lst)
# Out:
# list

# %%
lst=['maths' ,'chemistry',100, 400, 200, 300]
type(lst)
len(lst)
# Out:
# 6

# %% [markdown]
# ##1) Append(function of list)

# %%
lst.append(500)
lst
lst[5]
while 'ánu'in lst:
  lst.remove('ánu')
  print(lst)

# %%
lst
# Out:
# ['maths', 'chemistry', 100, 400, 200, 300, 500]

# %%
lst.remove(500)
print(lst)
# Out:
# ['maths', 'chemistry', 100, 400, 200, 300]

# %%
lst[1:]
lst[1:5]
# Out:
# ['chemistry', 100, 400, 200]

# %% [markdown]
# ## 2) Insert

# %%
lst.insert(1, 'priya')
lst
# Out:
# ['maths',
#  'priya',
#  'priya',
#  'priya',
#  'priya',
#  'priya',
#  'chemistry',
#  100,
#  400,
#  200,
#  300]

# %%
# Ensure 'priya' is at index 1 and only appears once in the list.


while 'priya' in lst:
    lst.remove('priya')
# so this insertion will place it uniquely at index 1.
lst.insert(1, 'priya')

print(lst)
# Out:
# ['maths', 'priya', 'chemistry', 100, 400, 200, 300]
